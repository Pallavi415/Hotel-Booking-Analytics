# %% [markdown]
# # Hotel Booking Analytics
#
# ## Data Loading and Initial Overview
#
# ### Objective
#
# This notebook focuses on loading the Hotel Booking Demand dataset and performing an initial assessment of its structure, dimensions, data types, and overall quality. The objective is to understand the dataset before any preprocessing or exploratory analysis.

# %%
## Import Required Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np 
import pandas as pd

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

plt.style.use("default")

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("../data/hotel_bookings.csv")

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %% [markdown]
# ## Dataset Shape

# %%
rows, columns = df.shape 
print(f"Number of Rows : {rows}")
print(f"Number of Columns : {columns}")
# Out:
# Number of Rows : 119390
# Number of Columns : 32

# %% [markdown]
# ## Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
## Statistical Summary

# %%
df.describe(include="all").T
# Out:
#                                    count unique         top    freq  \
# hotel                             119390      2  City Hotel   79330
# is_canceled                     119390.0    NaN         NaN     NaN
# lead_time                       119390.0    NaN         NaN     NaN
# arrival_date_year               119390.0    NaN         NaN     NaN
# arrival_date_month                119390     12      August   13877
# arrival_date_week_number        119390.0    NaN         NaN     NaN
# arrival_date_day_of_month       119390.0    NaN         NaN     NaN
# stays_in_weekend_nights         119390.0    NaN         NaN     NaN
# stays_in_week_nights            119390.0    NaN         NaN     NaN
# adults                          119390.0    NaN         NaN     NaN
# children                        119386.0    NaN         NaN     NaN
# babies                          119390.0    NaN         NaN     NaN
# meal                              119390      5          BB   92310
# ...

# %%
## First Five Records

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
## Last Five Records

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ## Dataset Profiling
#
# This section provides a high-level overview of the dataset, including the list of features, data types, missing values, duplicate records, and memory usage. These checks help identify potential data quality issues before preprocessing.

# %%
#Display Column Names 
df.columns.tolist()
# Out:
# ['hotel',
#  'is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'reserved_room_type',
#  'assigned_room_type',
#  'booking_changes',
#  'deposit_type',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'customer_type',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'reservation_status',
#  'reservation_status_date']

# %%
#Check Data Types
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
#Missing Values

# %%
missing_values = pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Percentage": (df.isnull().sum()/len(df))*100
})

missing_values = missing_values[missing_values["Missing Values"] > 0]
missing_values.sort_values("Percentage", ascending=False)
# Out:
#           Missing Values  Percentage
# company           112593   94.306893
# agent              16340   13.686238
# country              488    0.408744
# children               4    0.003350

# %%
#Duplicate Records

# %%
print(f"Duplicate Records : {df.duplicated().sum()}")
# Out:
# Duplicate Records : 31994

# %%
#Memory Usage

# %%
memory = df.memory_usage(deep=True).sum() / (1024**2)

print(f"Memory Usage : {memory:.2f} MB")
# Out:
# Memory Usage : 93.90 MB

# %%
#Numerical Features
numerical_columns = df.select_dtypes(include=np.number).columns.tolist()

print("Number of Numerical Features :", len(numerical_columns))
numerical_columns
# Out:
# Number of Numerical Features : 20
# ['is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'booking_changes',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests']

# %%
#Categorical Features
categorical_columns = df.select_dtypes(include="object").columns.tolist()

print("Number of Categorical Features :", len(categorical_columns))
categorical_columns
# Out:
# Number of Categorical Features : 12
# ['hotel',
#  'arrival_date_month',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'reserved_room_type',
#  'assigned_room_type',
#  'deposit_type',
#  'customer_type',
#  'reservation_status',
#  'reservation_status_date']

# %%
#Unique Values
pd.DataFrame({
    "Unique Values": df.nunique()
}).sort_values("Unique Values", ascending=False)
# Out:
#                                 Unique Values
# adr                                      8879
# reservation_status_date                   926
# lead_time                                 479
# company                                   352
# agent                                     333
# country                                   177
# days_in_waiting_list                      128
# previous_bookings_not_canceled             73
# arrival_date_week_number                   53
# stays_in_week_nights                       35
# arrival_date_day_of_month                  31
# booking_changes                            21
# stays_in_weekend_nights                    17
# previous_cancellations                     15
# adults                                     14
# arrival_date_month                         12
# assigned_room_type                         12
# reserved_room_type                         10
# market_segment                              8
# ...

# %%
#Random Sample
df.sample(5, random_state=42)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 30946   Resort Hotel            0        203               2016
# 40207     City Hotel            1         82               2015
# 103708    City Hotel            0         25               2016
# 85144     City Hotel            0          1               2016
# 109991    City Hotel            0         70               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 30946            December                        49
# 40207                July                        29
# 103708           December                        53
# 85144               March                        11
# 109991              April                        16
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 30946                           2                        2
# 40207                          16                        0
# 103708                         27                        0
# ...

# %% [markdown]
# ## Initial Data Quality Assessment
#
# This section evaluates the overall quality of the dataset by examining missing values, duplicate records, and feature types. Understanding these characteristics is essential before performing data cleaning and exploratory analysis.

# %%
#Check Missing Values
missing_values = pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Percentage (%)": round((df.isnull().sum() / len(df)) * 100, 2)
})

missing_values = missing_values[missing_values["Missing Values"] > 0]
missing_values.sort_values(by="Percentage (%)", ascending=False)
# Out:
#           Missing Values  Percentage (%)
# company           112593           94.31
# agent              16340           13.69
# country              488            0.41
# children               4            0.00

# %%
#Check Duplicate Records
duplicate_count = df.duplicated().sum()

print(f"Total Duplicate Records: {duplicate_count}")
# Out:
# Total Duplicate Records: 31994

# %%
#Feature Classification

# %%
numerical_features = df.select_dtypes(include=["int64", "float64"]).columns.tolist()
categorical_features = df.select_dtypes(include=["object"]).columns.tolist()

print(f"Number of Numerical Features   : {len(numerical_features)}")
print(f"Number of Categorical Features : {len(categorical_features)}")
# Out:
# Number of Numerical Features   : 20
# Number of Categorical Features : 12

# %%
#Display Feature Lists

# %%
print("Numerical Features:\n")
print(numerical_features)
# Out:
# Numerical Features:
#
# ['is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'agent', 'company', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']

# %%
print("Categorical Features:\n")
print(categorical_features)
# Out:
# Categorical Features:
#
# ['hotel', 'arrival_date_month', 'meal', 'country', 'market_segment', 'distribution_channel', 'reserved_room_type', 'assigned_room_type', 'deposit_type', 'customer_type', 'reservation_status', 'reservation_status_date']

# %%
#Unique Values in Each Feature

# %%
unique_values = pd.DataFrame({
    "Feature": df.columns,
    "Unique Values": df.nunique().values
})

unique_values.sort_values(by="Unique Values", ascending=False)
# Out:
#                            Feature  Unique Values
# 27                             adr           8879
# 31         reservation_status_date            926
# 2                        lead_time            479
# 24                         company            352
# 23                           agent            333
# 13                         country            177
# 25            days_in_waiting_list            128
# 18  previous_bookings_not_canceled             73
# 5         arrival_date_week_number             53
# 8             stays_in_week_nights             35
# 6        arrival_date_day_of_month             31
# 21                 booking_changes             21
# 7          stays_in_weekend_nights             17
# 17          previous_cancellations             15
# 9                           adults             14
# 4               arrival_date_month             12
# 20              assigned_room_type             12
# 19              reserved_room_type             10
# ...

# %%
#Random Sample

# %%
df.sample(5, random_state=42)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 30946   Resort Hotel            0        203               2016
# 40207     City Hotel            1         82               2015
# 103708    City Hotel            0         25               2016
# 85144     City Hotel            0          1               2016
# 109991    City Hotel            0         70               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 30946            December                        49
# 40207                July                        29
# 103708           December                        53
# 85144               March                        11
# 109991              April                        16
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 30946                           2                        2
# 40207                          16                        0
# 103708                         27                        0
# ...

# %% [markdown]
# ## Summary
#
# The dataset has been successfully loaded and examined. The initial assessment provided information about its dimensions, data types, missing values, duplicate records, and feature categories.
